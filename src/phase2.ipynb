# %%
import json
import urllib.request


def queue_prompt(prompt_workflow):
    """ComfyUIサーバーにジョブを送信する"""
    p = {"prompt": prompt_workflow}
    data = json.dumps(p).encode("utf-8")
    # Paperspace環境内のComfyUI（ポート6006）へリクエスト
    req = urllib.request.Request("http://127.0.0.1:6006/prompt", data=data)
    with urllib.request.urlopen(req) as response:
        return json.loads(response.read())

# %%
# 1. API JSONファイルの読み込み
with open("./src/param/26.2.23_phase2_api_export_test.json", "r", encoding="utf-8") as f:
    prompt = json.load(f)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[3], line 2
#       1 # 1. API JSONファイルの読み込み
# ----> 2 with open("./src/param/26.2.23_phase2_api_export_test.json", "r", encoding="utf-8") as f:
#       3     prompt = json.load(f)
#
# File /opt/conda/lib/python3.11/site-packages/IPython/core/interactiveshell.py:324, in _modified_open(file, *args, **kwargs)
#     317 if file in {0, 1, 2}:
#     318     raise ValueError(
#     319         f"IPython won't let you open fd={file} by default "
#     320         "as it is likely to crash IPython. If you know what you are doing, "
#     321         "you can use builtins' open."
#     322     )
# --> 324 return io_open(file, *args, **kwargs)
#
# FileNotFoundError: [Errno 2] No such file or directory: './src/param/26.2.23_phase2_api_export_test.json'

# %%
# 2. パラメータの動的書き換え（自動化の核心）
prompt["6"]["inputs"]["text"] = "a cybernetic owl with glowing eyes, digital art, high quality"
prompt["3"]["inputs"]["seed"] = 123456789  # 任意の値に変更

# %%
# 3. 実行
print("🚀 生成ジョブを送信中...")
result = queue_prompt(prompt)
print(f"✅ 受付完了: Prompt ID = {result['prompt_id']}")
